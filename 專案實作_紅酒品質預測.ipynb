# %% [markdown]
# <a href="https://colab.research.google.com/github/Seanwu003/Prediction-of-quality-of-Wine/blob/main/%E5%B0%88%E6%A1%88%E5%AF%A6%E4%BD%9C_%E7%B4%85%E9%85%92%E5%93%81%E8%B3%AA%E9%A0%90%E6%B8%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# 請找出其他欄位的定義?
# * fixed acidity
#
#   most acids involved with wine or fixed or nonvolatile (do not evaporate readily)
# *  volatile acidity
#
#   the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste
# *   citric acid
#
#   found in small quantities, citric acid can add 'freshness' and flavor to wines
# *   residual sugar
#
#   the amount of sugar remaining after fermentation stops, it's rare to find wines with less than 1 gram/liter and wines with greater than 45 grams/liter are considered sweet
# *   chlorides 鈉含量
#
#   the amount of salt in the wine
#
# *   free sulfur dioxide
#
#   the free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion; it prevents microbial growth and the oxidation of wine
# *   total sulfur dioxide
#
#   amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable in wine, but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine
# *   density
#
#   the density of water is close to that of water depending on the percent alcohol and sugar content
#
# *   pH 酸鹼值
#
#   describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4 on the pH scale
#
# *   sulphates
#
#   a wine additive which can contribute to sulfur dioxide gas (S02) levels, wich acts as an antimicrobial and antioxidant

# %% [markdown]
#  請你嘗試觀察每一個「特徵」欄位（除 quality 外）資料的分佈情況，有看出什麼結果嗎？

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_x = df.drop('quality', axis = 1)
df_y = df['quality']
corr = df.corr()
#看熱力圖
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
sns.heatmap(
        corr,
        cmap = cmap,
        square=True,
        cbar_kws={ 'shrink' : .9 },
        ax = plt.subplots( figsize =( 12 , 10 ) )[1],
        annot = True,
        annot_kws = { 'fontsize' : 12 }
)
# Out:
# <Axes: >

# %%
import numpy as np

# Generating a mock dataset with similar structure
np.random.seed(42)
mock_data = {
    'fixed_acidity': np.random.normal(8.3, 1.5, 1000),
    'volatile_acidity': np.random.normal(0.5, 0.1, 1000),
    'citric_acid': np.random.normal(0.3, 0.1, 1000),
    'residual_sugar': np.random.normal(2.5, 1.0, 1000),
    'chlorides': np.random.normal(0.08, 0.02, 1000),
    'free_sulfur_dioxide': np.random.normal(15, 5, 1000),
    'total_sulfur_dioxide': np.random.normal(46, 15, 1000),
    'density': np.random.normal(0.996, 0.002, 1000),
    'pH': np.random.normal(3.3, 0.1, 1000),
    'sulphates': np.random.normal(0.65, 0.1, 1000),
    'alcohol': np.random.normal(10.5, 1.0, 1000),
    'quality': np.random.randint(3, 9, 1000)
}
df = pd.DataFrame(mock_data)
features = df.drop(columns=['quality'])

# Summary statistics and visualization for each feature
distribution_summary = features.describe()
distribution_summary
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1000.000000       1000.000000  1000.000000     1000.000000
# mean        8.328998          0.507084     0.300583        2.481281
# std         1.468824          0.099745     0.098345        1.027133
# min         3.438099          0.205961    -0.001951       -0.429449
# 25%         7.328615          0.439376     0.235200        1.762580
# 50%         8.337951          0.506308     0.299975        2.500185
# 75%         9.271916          0.572888     0.366092        3.166945
# max        14.079097          0.819311     0.692624        5.743093
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1000.000000          1000.000000           1000.000000  1000.000000
# mean      0.079015            14.766312             45.577652     0.996038
# std       0.019848             5.036946             15.375067     0.002083
# min       0.016466             0.502431              5.310812     0.988623
# 25%       0.066348            11.531536             34.672940     0.994616
# 50%       0.079635            14.785865             45.178804     0.996010
# 75%       0.092782            18.062234             56.496176     0.997447
# max       0.142258            30.491497             98.935828     1.002235
#
#                 pH    sulphates      alcohol
# count  1000.000000  1000.000000  1000.000000
# mean      3.301834     0.648797    10.460091
# std       0.101169     0.096512     0.970404
# min       2.916334     0.257760     7.267435
# 25%       3.236315     0.585667     9.813101
# 50%       3.301912     0.650437    10.443686
# 75%       3.367720     0.715074    11.112335
# max       3.637738     0.926837    13.414109
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# distribution_summary['fixed_acidity'].plot(kind='hist', bins=20, title='fixed_acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['volatile_acidity'].plot(kind='hist', bins=20, title='volatile_acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['citric_acid'].plot(kind='hist', bins=20, title='citric_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['residual_sugar'].plot(kind='hist', bins=20, title='residual_sugar')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# distribution_summary.plot(kind='scatter', x='fixed_acidity', y='volatile_acidity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary.plot(kind='scatter', x='volatile_acidity', y='citric_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary.plot(kind='scatter', x='citric_acid', y='residual_sugar', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary.plot(kind='scatter', x='residual_sugar', y='chlorides', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# distribution_summary['fixed_acidity'].plot(kind='line', figsize=(8, 4), title='fixed_acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['volatile_acidity'].plot(kind='line', figsize=(8, 4), title='volatile_acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['citric_acid'].plot(kind='line', figsize=(8, 4), title='citric_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# distribution_summary['residual_sugar'].plot(kind='line', figsize=(8, 4), title='residual_sugar')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['fixed_acidity'].plot(kind='hist', bins=20, title='fixed_acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['volatile_acidity'].plot(kind='hist', bins=20, title='volatile_acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['citric_acid'].plot(kind='hist', bins=20, title='citric_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['residual_sugar'].plot(kind='hist', bins=20, title='residual_sugar')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='fixed_acidity', y='volatile_acidity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='volatile_acidity', y='citric_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='citric_acid', y='residual_sugar', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='residual_sugar', y='chlorides', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['fixed_acidity'].plot(kind='line', figsize=(8, 4), title='fixed_acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['volatile_acidity'].plot(kind='line', figsize=(8, 4), title='volatile_acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['citric_acid'].plot(kind='line', figsize=(8, 4), title='citric_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['residual_sugar'].plot(kind='line', figsize=(8, 4), title='residual_sugar')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='fixed_acidity', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='volatile_acidity', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='citric_acid', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='residual_sugar', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing the distribution of each feature
for column in features.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(features[column], kde=True, bins=30, color='skyblue', alpha=0.7)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Plotting boxplots for each feature
for column in features.columns:
    plt.figure(figsize=(8, 5))
    sns.boxplot(y=features[column], color='lightblue', width=0.5)
    plt.title(f'Box Plot of {column}')
    plt.ylabel(column)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# 發現特徵值幾乎都有很好的一個分佈樣態，符合常態分配

# %% [markdown]
# 請你嘗試觀察每一個「標籤」欄位（quality）資料的分佈情況，有看出什麼結果嗎？

# %%
target = df_x

# Plotting the distribution of the target variable ('quality')
plt.figure(figsize=(8, 5))
sns.countplot(x=df['quality'], palette='viridis')
plt.title('Distribution of Quality Ratings')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-19-c88721967a20>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['quality'], palette='viridis')

# %% [markdown]
# 似乎沒有明顯的樣態
